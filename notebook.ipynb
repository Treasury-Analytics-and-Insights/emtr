# %%
#import js
import pandas as pd
import matplotlib.pyplot as plt

#from pyodide.http import open_url
#from pyodide.ffi import create_proxy

data = pd.read_csv('dist_exp_data.csv')

plot_data = data[(data['Income Type'] == 'Income Quantiles') & (data['Population Type'] == 'Household') & (data.Description == 'All households') & (data['Income Measure'] == 'Taxable Income')][['Income Group','Value']]
plot_data.Value = plot_data.Value.astype(int)

fig, ax = plt.subplots()
bars = ax.barh(plot_data['Income Group'], plot_data.Value, height=0.7)
ax.bar_label(bars)
plt.title("Stuff")
# Out:
# Text(0.5, 1.0, 'Stuff')

# %%
plot_data.to_html(columns=['Income Group', 'Value'])
# Out:
# '<table border="1" class="dataframe">\n  <thead>\n    <tr style="text-align: right;">\n      <th></th>\n      <th>Income Group</th>\n      <th>Value</th>\n    </tr>\n  </thead>\n  <tbody>\n    <tr>\n      <th>4006</th>\n      <td>1</td>\n      <td>12300</td>\n    </tr>\n    <tr>\n      <th>4007</th>\n      <td>2</td>\n      <td>23400</td>\n    </tr>\n    <tr>\n      <th>4008</th>\n      <td>3</td>\n      <td>27200</td>\n    </tr>\n    <tr>\n      <th>4009</th>\n      <td>4</td>\n      <td>35500</td>\n    </tr>\n    <tr>\n      <th>4010</th>\n      <td>5</td>\n      <td>41600</td>\n    </tr>\n    <tr>\n      <th>4011</th>\n      <td>6</td>\n      <td>49100</td>\n    </tr>\n    <tr>\n      <th>4012</th>\n      <td>7</td>\n      <td>58100</td>\n    </tr>\n    <tr>\n      <th>4013</th>\n      <td>8</td>\n      <td>67500</td>\n    </tr>\n    <tr>\n      <th>4014</th>\n      <td>9</td>\n      <td>77500</td>\n    </tr>\n    <tr>\n      <th>4015</th>\n      <td>10</td>\n      <td>87500</td>\
# ...

# %%
data['Income Measure'].unique()
# Out:
# array(['Equivalised Disposable Income', 'Disposable Income',
#        'Total Income', 'Taxable Income'], dtype=object)

# %%
def get_plot_data(income_type):
    plot_data = data[(data['Income Type'] == 'Income Quantiles') & 
                     (data['Population Type'] == 'Households') & 
                     (data.Description == 'All households') & 
                     (data['Income Measure'] == income_type)][['Income Group','Value']]
    plot_data.Value = plot_data.Value.astype(int)
    return(plot_data)

# %%
data[data['Population Type'] == 'Family']
# Out:
#       Unnamed: 0  Index Income Group       Income Type Population Type  \
# 707          707    708            1  Income Quantiles          Family
# 708          708    709            2  Income Quantiles          Family
# 709          709    710            3  Income Quantiles          Family
# 710          710    711            4  Income Quantiles          Family
# 711          711    712            5  Income Quantiles          Family
# ...          ...    ...          ...               ...             ...
# 5323        5323   5324  $220k-$240k      Income Bands          Family
# 5324        5324   5325  $240k-$260k      Income Bands          Family
# 5325        5325   5326  $260k-$280k      Income Bands          Family
# 5326        5326   5327  $280k-$300k      Income Bands          Family
# 5327        5327   5328  Above $300k      Income Bands          Family
#
#                 Description                 Income Measure   Value Population
# ...

# %%
len(data.Description.unique())
# Out:
# 21

# %%
data.Value.str.isnumeric()
# Out:
# 0        True
# 1        True
# 2        True
# 3        True
# 4        True
#         ...
# 5323    False
# 5324     True
# 5325    False
# 5326    False
# 5327     True
# Name: Value, Length: 5328, dtype: bool

# %%
data = pd.read_csv('dist_exp_data.csv')

# %%
new_data = data.drop('Unnamed: 0', axis=1)

# %%
new_data
# Out:
#       Index Income Group       Income Type Population Type  \
# 0         1            1  Income Quantiles       Household
# 1         2            2  Income Quantiles       Household
# 2         3            3  Income Quantiles       Household
# 3         4            4  Income Quantiles       Household
# 4         5            5  Income Quantiles       Household
# ...     ...          ...               ...             ...
# 5323   5324  $220k-$240k      Income Bands          Family
# 5324   5325  $240k-$260k      Income Bands          Family
# 5325   5326  $260k-$280k      Income Bands          Family
# 5326   5327  $280k-$300k      Income Bands          Family
# 5327   5328  Above $300k      Income Bands          Family
#
#                 Description                 Income Measure   Value Population
# 0            All households  Equivalised Disposable Income   11700      89000
# 1            All households  Equivalised Disposable Income   20900      89000
# ...

# %%
new_data.to_csv('dist_exp_data.csv', index=False)
